# %% [markdown]
# ### 1. Grid Search (RF)

# %%
import pandas as pd
import numpy as np

from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

# 1. Load data
df = pd.read_csv('mobile_clsfn_train.csv')

# 2. Create input features(X)
X = df.drop(columns=['price_range'], axis=1).values

# 3. Creating target variable(y)
y = df['price_range'].values

# 4. Initializing Random Forest model
classifier = ensemble.RandomForestClassifier()

# 5. Parameters we want to tune
param_grid = {
    'n_estimators': [100, 200, 300, 400],
    'max_depth': [1, 3, 5, 7],
    'criterion': ['gini', 'entropy']
}

# 6. Initializing GridSearch
model = model_selection.GridSearchCV(
    estimator = classifier,
    param_grid = param_grid,
    scoring = 'accuracy',
    verbose = 10,
    cv = 5
)

# 7. Run GridSearch
model.fit(X, y)

# 8. Get the best parameters
print("\nAccuracy:", model.best_score_)
print("\nBest parameters(RF):", model.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.542 total time=   0.0s
# [CV 2/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.560 total time=   0.1s
# [CV 3/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.623 total time=   0.0s
# [CV 4/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.615 total time=   0.1s
# [CV 5/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.562 total time=   0.0s
# [CV 1/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 1/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.585 total time=   0.2s
# [CV 2/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 2/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.588 total time=   0.2s
# [CV 3/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 3/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.578 total time=   0.2s
# [CV 4/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 4/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.598 total time=   0.2s
# [CV 5/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 5/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.598 total time=   0.2s
# [CV 1/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.550 total time=   0.3s
# [CV 2/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.605 total time=   0.3s
# [CV 3/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.605 total time=   0.3s
# [CV 4/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.565 total time=   0.3s
# [CV 5/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.580 total time=   0.3s
# [CV 1/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.595 total time=   0.5s
# [CV 2/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.585 total time=   0.5s
# [CV 3/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.595 total time=   0.5s
# [CV 4/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.593 total time=   0.5s
# [CV 5/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.580 total time=   0.5s
# [CV 1/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 1/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.797 total time=   0.1s
# [CV 2/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 2/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 3/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 3/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.828 total time=   0.1s
# [CV 4/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 4/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 5/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 5/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.802 total time=   0.1s
# [CV 1/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 1/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.787 total time=   0.3s
# [CV 2/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 2/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.782 total time=   0.3s
# [CV 3/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 3/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.828 total time=   0.3s
# [CV 4/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 4/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.818 total time=   0.3s
# [CV 5/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 5/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.792 total time=   0.3s
# [CV 1/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 1/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.797 total time=   0.5s
# [CV 2/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 2/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.797 total time=   0.5s
# [CV 3/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 3/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.835 total time=   0.5s
# [CV 4/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 4/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.825 total time=   0.5s
# [CV 5/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 5/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.797 total time=   0.5s
# [CV 1/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 1/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.782 total time=   0.6s
# [CV 2/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 2/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.800 total time=   0.7s
# [CV 3/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 3/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.828 total time=   0.7s
# [CV 4/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 4/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.810 total time=   0.6s
# [CV 5/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 5/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.790 total time=   0.7s
# [CV 1/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 1/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.807 total time=   0.1s
# [CV 2/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 2/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.858 total time=   0.1s
# [CV 3/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 3/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.868 total time=   0.1s
# [CV 4/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 4/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 5/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 5/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.828 total time=   0.1s
# [CV 1/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 1/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.845 total time=   0.4s
# [CV 2/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 2/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.843 total time=   0.4s
# [CV 3/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 3/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.863 total time=   0.4s
# [CV 4/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 4/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.833 total time=   0.4s
# [CV 5/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 5/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 1/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 1/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.828 total time=   0.6s
# [CV 2/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 2/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.845 total time=   0.6s
# [CV 3/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 3/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.870 total time=   0.6s
# [CV 4/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 4/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.835 total time=   0.6s
# [CV 5/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 5/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.818 total time=   0.6s
# [CV 1/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 1/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.828 total time=   0.8s
# [CV 2/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 2/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.835 total time=   0.8s
# [CV 3/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 3/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.868 total time=   0.8s
# [CV 4/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 4/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.838 total time=   0.8s
# [CV 5/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 5/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.830 total time=   0.8s
# [CV 1/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 1/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.860 total time=   0.2s
# [CV 2/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 2/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.858 total time=   0.2s
# [CV 3/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 3/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.873 total time=   0.2s
# [CV 4/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 4/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.868 total time=   0.2s
# [CV 5/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 5/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.838 total time=   0.2s
# [CV 1/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 1/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.875 total time=   0.5s
# [CV 2/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 2/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.873 total time=   0.5s
# [CV 3/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 3/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.885 total time=   0.5s
# [CV 4/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 4/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.858 total time=   0.5s
# [CV 5/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 5/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.838 total time=   0.5s
# [CV 1/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 1/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.868 total time=   0.7s
# [CV 2/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 2/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.880 total time=   0.7s
# [CV 3/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 3/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.887 total time=   0.7s
# [CV 4/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 4/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.863 total time=   0.7s
# [CV 5/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 5/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.845 total time=   0.7s
# [CV 1/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 1/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.863 total time=   1.0s
# [CV 2/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 2/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.870 total time=   1.0s
# [CV 3/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 3/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.885 total time=   1.1s
# [CV 4/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 4/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.860 total time=   1.1s
# [CV 5/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 5/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.853 total time=   1.1s
# [CV 1/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 1/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.542 total time=   0.1s
# [CV 2/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 2/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.580 total time=   0.1s
# [CV 3/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 3/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.547 total time=   0.1s
# [CV 4/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 4/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.557 total time=   0.1s
# [CV 5/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 5/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.547 total time=   0.1s
# [CV 1/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 1/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.575 total time=   0.2s
# [CV 2/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 2/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.557 total time=   0.2s
# [CV 3/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 3/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.540 total time=   0.2s
# [CV 4/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 4/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.542 total time=   0.2s
# [CV 5/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 5/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.535 total time=   0.2s
# [CV 1/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 1/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.580 total time=   0.4s
# [CV 2/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 2/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.542 total time=   0.4s
# [CV 3/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 3/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.537 total time=   0.4s
# [CV 4/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 4/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.525 total time=   0.4s
# [CV 5/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 5/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.555 total time=   0.4s
# [CV 1/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 1/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.583 total time=   0.5s
# [CV 2/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 2/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.550 total time=   0.5s
# [CV 3/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 3/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.550 total time=   0.5s
# [CV 4/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 4/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.555 total time=   0.5s
# [CV 5/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 5/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.557 total time=   0.5s
# [CV 1/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 1/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.795 total time=   0.1s
# [CV 2/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 2/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.790 total time=   0.1s
# [CV 3/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 3/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.797 total time=   0.1s
# [CV 4/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 4/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.735 total time=   0.1s
# [CV 5/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 5/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.690 total time=   0.1s
# [CV 1/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 1/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.815 total time=   0.3s
# [CV 2/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 2/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.750 total time=   0.3s
# [CV 3/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 3/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.723 total time=   0.3s
# [CV 4/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 4/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.757 total time=   0.3s
# [CV 5/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 5/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.787 total time=   0.3s
# [CV 1/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 1/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.782 total time=   0.5s
# [CV 2/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 2/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.723 total time=   0.6s
# [CV 3/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 3/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.800 total time=   0.6s
# [CV 4/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 4/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.765 total time=   0.7s
# [CV 5/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 5/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.755 total time=   0.6s
# [CV 1/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 1/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.780 total time=   0.8s
# [CV 2/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 2/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.757 total time=   1.5s
# [CV 3/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 3/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.775 total time=   1.0s
# [CV 4/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 4/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.780 total time=   1.1s
# [CV 5/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 5/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.775 total time=   0.9s
# [CV 1/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 1/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.840 total time=   0.2s
# [CV 2/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 2/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.815 total time=   0.2s
# [CV 3/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 3/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.858 total time=   0.2s
# [CV 4/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 4/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.843 total time=   0.2s
# [CV 5/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 5/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.840 total time=   0.2s
# [CV 1/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 1/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.810 total time=   0.6s
# [CV 2/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 2/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.845 total time=   0.6s
# [CV 3/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 3/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.835 total time=   0.6s
# [CV 4/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 4/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.838 total time=   0.6s
# [CV 5/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 5/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.850 total time=   0.6s
# [CV 1/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 1/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.838 total time=   0.9s
# [CV 2/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 2/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.838 total time=   0.9s
# [CV 3/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 3/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.860 total time=   0.9s
# [CV 4/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 4/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.828 total time=   0.7s
# [CV 5/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 5/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.848 total time=   0.8s
# [CV 1/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 1/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.840 total time=   1.0s
# [CV 2/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 2/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.848 total time=   1.6s
# [CV 3/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 3/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.873 total time=   1.4s
# [CV 4/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 4/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.830 total time=   1.3s
# [CV 5/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 5/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.843 total time=   1.2s
# [CV 1/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 1/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.855 total time=   0.3s
# [CV 2/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 2/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.853 total time=   0.3s
# [CV 3/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 3/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.880 total time=   0.3s
# [CV 4/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 4/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.838 total time=   0.3s
# [CV 5/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 5/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.850 total time=   0.3s
# [CV 1/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 1/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.858 total time=   0.7s
# [CV 2/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 2/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.865 total time=   0.7s
# [CV 3/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 3/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.890 total time=   0.8s
# [CV 4/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 4/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.848 total time=   0.7s
# [CV 5/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 5/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.853 total time=   0.7s
# [CV 1/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 1/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.863 total time=   1.2s
# [CV 2/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 2/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.877 total time=   1.2s
# [CV 3/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 3/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.895 total time=   1.2s
# [CV 4/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 4/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.855 total time=   1.1s
# [CV 5/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 5/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.860 total time=   1.1s
# [CV 1/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 1/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.863 total time=   1.3s
# [CV 2/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 2/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.877 total time=   1.3s
# [CV 3/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 3/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.902 total time=   1.3s
# [CV 4/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 4/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.848 total time=   1.3s
# [CV 5/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 5/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.848 total time=   1.3s
#
# Accuracy: 0.8699999999999999
#
# Best parameters(RF): {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 300, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ### 2. Random Search(RF)

# %%
import pandas as pd
import numpy as np

from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

# 1. Load data
df = pd.read_csv('mobile_clsfn_train.csv')

# 2. Create input features(X)
X = df.drop(columns=['price_range'], axis=1).values

# 3. Creating target variable(y)
y = df['price_range'].values

# 4. Initializing Random Forest model
classifier = ensemble.RandomForestClassifier()

# 5. Parameters we want to tune
param_grid = {
    'n_estimators': np.arange(100, 1500, 100),
    'max_depth': np.arange(1, 20),
    'criterion': ['gini', 'entropy']
}

# 6. Initializing Random Search
model = model_selection.RandomizedSearchCV(
    estimator = classifier,
    param_distributions = param_grid,
    n_iter = 10,
    scoring = 'accuracy',
    verbose = 10,
    cv = 5
)

# 7. Run Random Search
model.fit(X, y)

# 8. Get the best parameters
print("\nAccuracy:", model.best_score_)
print("\nBest parameters(RF):", model.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=entropy, max_depth=7, n_estimators=400...........
# [CV 1/5; 1/10] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.853 total time=   1.3s
# [CV 2/5; 1/10] START criterion=entropy, max_depth=7, n_estimators=400...........
# [CV 2/5; 1/10] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.860 total time=   1.3s
# [CV 3/5; 1/10] START criterion=entropy, max_depth=7, n_estimators=400...........
# [CV 3/5; 1/10] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.895 total time=   1.3s
# [CV 4/5; 1/10] START criterion=entropy, max_depth=7, n_estimators=400...........
# [CV 4/5; 1/10] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.860 total time=   1.3s
# [CV 5/5; 1/10] START criterion=entropy, max_depth=7, n_estimators=400...........
# [CV 5/5; 1/10] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.848 total time=   1.3s
# [CV 1/5; 2/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 1/5; 2/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.845 total time=   5.2s
# [CV 2/5; 2/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 2/5; 2/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.855 total time=   4.6s
# [CV 3/5; 2/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 3/5; 2/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.882 total time=   4.4s
# [CV 4/5; 2/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 4/5; 2/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.850 total time=   4.2s
# [CV 5/5; 2/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 5/5; 2/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.830 total time=   3.8s
# [CV 1/5; 3/10] START criterion=entropy, max_depth=15, n_estimators=200..........
# [CV 1/5; 3/10] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.897 total time=   1.1s
# [CV 2/5; 3/10] START criterion=entropy, max_depth=15, n_estimators=200..........
# [CV 2/5; 3/10] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.887 total time=   1.0s
# [CV 3/5; 3/10] START criterion=entropy, max_depth=15, n_estimators=200..........
# [CV 3/5; 3/10] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.907 total time=   1.0s
# [CV 4/5; 3/10] START criterion=entropy, max_depth=15, n_estimators=200..........
# [CV 4/5; 3/10] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.880 total time=   1.0s
# [CV 5/5; 3/10] START criterion=entropy, max_depth=15, n_estimators=200..........
# [CV 5/5; 3/10] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.858 total time=   1.0s
# [CV 1/5; 4/10] START criterion=entropy, max_depth=1, n_estimators=600...........
# [CV 1/5; 4/10] END criterion=entropy, max_depth=1, n_estimators=600;, score=0.575 total time=   1.0s
# [CV 2/5; 4/10] START criterion=entropy, max_depth=1, n_estimators=600...........
# [CV 2/5; 4/10] END criterion=entropy, max_depth=1, n_estimators=600;, score=0.555 total time=   1.0s
# [CV 3/5; 4/10] START criterion=entropy, max_depth=1, n_estimators=600...........
# [CV 3/5; 4/10] END criterion=entropy, max_depth=1, n_estimators=600;, score=0.550 total time=   1.0s
# [CV 4/5; 4/10] START criterion=entropy, max_depth=1, n_estimators=600...........
# [CV 4/5; 4/10] END criterion=entropy, max_depth=1, n_estimators=600;, score=0.557 total time=   1.1s
# [CV 5/5; 4/10] START criterion=entropy, max_depth=1, n_estimators=600...........
# [CV 5/5; 4/10] END criterion=entropy, max_depth=1, n_estimators=600;, score=0.550 total time=   1.1s
# [CV 1/5; 5/10] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 5/10] END criterion=gini, max_depth=1, n_estimators=300;, score=0.605 total time=   0.4s
# [CV 2/5; 5/10] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 5/10] END criterion=gini, max_depth=1, n_estimators=300;, score=0.600 total time=   0.5s
# [CV 3/5; 5/10] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 5/10] END criterion=gini, max_depth=1, n_estimators=300;, score=0.627 total time=   0.5s
# [CV 4/5; 5/10] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 5/10] END criterion=gini, max_depth=1, n_estimators=300;, score=0.573 total time=   0.4s
# [CV 5/5; 5/10] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 5/10] END criterion=gini, max_depth=1, n_estimators=300;, score=0.595 total time=   0.5s
# [CV 1/5; 6/10] START criterion=gini, max_depth=4, n_estimators=1400.............
# [CV 1/5; 6/10] END criterion=gini, max_depth=4, n_estimators=1400;, score=0.815 total time=   3.5s
# [CV 2/5; 6/10] START criterion=gini, max_depth=4, n_estimators=1400.............
# [CV 2/5; 6/10] END criterion=gini, max_depth=4, n_estimators=1400;, score=0.828 total time=   3.5s
# [CV 3/5; 6/10] START criterion=gini, max_depth=4, n_estimators=1400.............
# [CV 3/5; 6/10] END criterion=gini, max_depth=4, n_estimators=1400;, score=0.843 total time=   3.7s
# [CV 4/5; 6/10] START criterion=gini, max_depth=4, n_estimators=1400.............
# [CV 4/5; 6/10] END criterion=gini, max_depth=4, n_estimators=1400;, score=0.815 total time=   3.7s
# [CV 5/5; 6/10] START criterion=gini, max_depth=4, n_estimators=1400.............
# [CV 5/5; 6/10] END criterion=gini, max_depth=4, n_estimators=1400;, score=0.805 total time=   3.5s
# [CV 1/5; 7/10] START criterion=entropy, max_depth=4, n_estimators=1200..........
# [CV 1/5; 7/10] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.820 total time=   3.8s
# [CV 2/5; 7/10] START criterion=entropy, max_depth=4, n_estimators=1200..........
# [CV 2/5; 7/10] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.815 total time=   3.6s
# [CV 3/5; 7/10] START criterion=entropy, max_depth=4, n_estimators=1200..........
# [CV 3/5; 7/10] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.835 total time=   3.5s
# [CV 4/5; 7/10] START criterion=entropy, max_depth=4, n_estimators=1200..........
# [CV 4/5; 7/10] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.830 total time=   3.7s
# [CV 5/5; 7/10] START criterion=entropy, max_depth=4, n_estimators=1200..........
# [CV 5/5; 7/10] END criterion=entropy, max_depth=4, n_estimators=1200;, score=0.825 total time=   3.7s
# [CV 1/5; 8/10] START criterion=entropy, max_depth=17, n_estimators=1400.........
# [CV 1/5; 8/10] END criterion=entropy, max_depth=17, n_estimators=1400;, score=0.890 total time=   7.8s
# [CV 2/5; 8/10] START criterion=entropy, max_depth=17, n_estimators=1400.........
# [CV 2/5; 8/10] END criterion=entropy, max_depth=17, n_estimators=1400;, score=0.890 total time=   7.8s
# [CV 3/5; 8/10] START criterion=entropy, max_depth=17, n_estimators=1400.........
# [CV 3/5; 8/10] END criterion=entropy, max_depth=17, n_estimators=1400;, score=0.907 total time=   8.4s
# [CV 4/5; 8/10] START criterion=entropy, max_depth=17, n_estimators=1400.........
# [CV 4/5; 8/10] END criterion=entropy, max_depth=17, n_estimators=1400;, score=0.873 total time=   8.1s
# [CV 5/5; 8/10] START criterion=entropy, max_depth=17, n_estimators=1400.........
# [CV 5/5; 8/10] END criterion=entropy, max_depth=17, n_estimators=1400;, score=0.873 total time=   6.9s
# [CV 1/5; 9/10] START criterion=entropy, max_depth=3, n_estimators=1000..........
# [CV 1/5; 9/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.760 total time=   2.6s
# [CV 2/5; 9/10] START criterion=entropy, max_depth=3, n_estimators=1000..........
# [CV 2/5; 9/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.775 total time=   2.7s
# [CV 3/5; 9/10] START criterion=entropy, max_depth=3, n_estimators=1000..........
# [CV 3/5; 9/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.800 total time=   2.3s
# [CV 4/5; 9/10] START criterion=entropy, max_depth=3, n_estimators=1000..........
# [CV 4/5; 9/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.770 total time=   2.7s
# [CV 5/5; 9/10] START criterion=entropy, max_depth=3, n_estimators=1000..........
# [CV 5/5; 9/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.765 total time=   2.2s
# [CV 1/5; 10/10] START criterion=gini, max_depth=9, n_estimators=400.............
# [CV 1/5; 10/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.877 total time=   1.8s
# [CV 2/5; 10/10] START criterion=gini, max_depth=9, n_estimators=400.............
# [CV 2/5; 10/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.875 total time=   1.6s
# [CV 3/5; 10/10] START criterion=gini, max_depth=9, n_estimators=400.............
# [CV 3/5; 10/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.892 total time=   1.6s
# [CV 4/5; 10/10] START criterion=gini, max_depth=9, n_estimators=400.............
# [CV 4/5; 10/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.868 total time=   1.5s
# [CV 5/5; 10/10] START criterion=gini, max_depth=9, n_estimators=400.............
# [CV 5/5; 10/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.858 total time=   1.5s
#
# Accuracy: 0.8865000000000001
#
# Best parameters(RF): {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 17, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 1400, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ### 3. Grid/Random Search with Pipelines

# %%
import pandas as pd
import numpy as np

from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection
from sklearn import decomposition
from sklearn import preprocessing
from sklearn import pipeline

df = pd.read_csv('mobile_clsfn_train.csv')

X = df.drop(columns=['price_range'], axis=1).values
y = df['price_range'].values

scl = preprocessing.StandardScaler()      # Standardization
pca = decomposition.PCA()                 # PCA
rf = ensemble.RandomForestClassifier()    # Random Forest

classifier = pipeline.Pipeline([('scaling', scl), ('pca', pca), ('rf', rf)])

param_grid = {
    'pca__n_components': np.arange(5, 10),
    'rf__n_estimators': np.arange(100, 1500, 100),
    'rf__max_depth': np.arange(1, 20),
    'rf__criterion': ['gini', 'entropy']
}

model = model_selection.RandomizedSearchCV(
    estimator = classifier,
    param_distributions = param_grid,
    n_iter = 10,
    scoring = 'accuracy',
    verbose = 10,
    cv = 5
)

model.fit(X, y)

print("\nAccuracy:", model.best_score_)
print("\nBest parameters(RF):", model.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300
# [CV 1/5; 1/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300;, score=0.360 total time=   1.8s
# [CV 2/5; 1/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300
# [CV 2/5; 1/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300;, score=0.407 total time=   1.7s
# [CV 3/5; 1/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300
# [CV 3/5; 1/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300;, score=0.275 total time=   1.7s
# [CV 4/5; 1/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300
# [CV 4/5; 1/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300;, score=0.390 total time=   2.2s
# [CV 5/5; 1/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300
# [CV 5/5; 1/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=9, rf__n_estimators=300;, score=0.263 total time=   2.5s
# [CV 1/5; 2/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100
# [CV 1/5; 2/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100;, score=0.407 total time=   9.5s
# [CV 2/5; 2/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100
# [CV 2/5; 2/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100;, score=0.458 total time=   8.2s
# [CV 3/5; 2/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100
# [CV 3/5; 2/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100;, score=0.477 total time=   6.9s
# [CV 4/5; 2/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100
# [CV 4/5; 2/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100;, score=0.512 total time=   6.6s
# [CV 5/5; 2/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100
# [CV 5/5; 2/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=1100;, score=0.420 total time=   8.6s
# [CV 1/5; 3/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700
# [CV 1/5; 3/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700;, score=0.385 total time=   2.3s
# [CV 2/5; 3/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700
# [CV 2/5; 3/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700;, score=0.427 total time=   2.0s
# [CV 3/5; 3/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700
# [CV 3/5; 3/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700;, score=0.450 total time=   1.5s
# [CV 4/5; 3/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700
# [CV 4/5; 3/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700;, score=0.463 total time=   1.5s
# [CV 5/5; 3/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700
# [CV 5/5; 3/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=2, rf__n_estimators=700;, score=0.438 total time=   1.5s
# [CV 1/5; 4/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200
# [CV 1/5; 4/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200;, score=0.412 total time=   0.7s
# [CV 2/5; 4/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200
# [CV 2/5; 4/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200;, score=0.458 total time=   0.7s
# [CV 3/5; 4/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200
# [CV 3/5; 4/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200;, score=0.468 total time=   0.7s
# [CV 4/5; 4/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200
# [CV 4/5; 4/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200;, score=0.463 total time=   0.7s
# [CV 5/5; 4/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200
# [CV 5/5; 4/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=3, rf__n_estimators=200;, score=0.435 total time=   0.7s
# [CV 1/5; 5/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100
# [CV 1/5; 5/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100;, score=0.307 total time=   0.5s
# [CV 2/5; 5/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100
# [CV 2/5; 5/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100;, score=0.340 total time=   0.5s
# [CV 3/5; 5/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100
# [CV 3/5; 5/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100;, score=0.292 total time=   0.5s
# [CV 4/5; 5/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100
# [CV 4/5; 5/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100;, score=0.312 total time=   0.5s
# [CV 5/5; 5/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100
# [CV 5/5; 5/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=100;, score=0.278 total time=   0.8s
# [CV 1/5; 6/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600
# [CV 1/5; 6/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600;, score=0.417 total time=   6.0s
# [CV 2/5; 6/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600
# [CV 2/5; 6/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600;, score=0.458 total time=   6.3s
# [CV 3/5; 6/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600
# [CV 3/5; 6/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600;, score=0.482 total time=   6.1s
# [CV 4/5; 6/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600
# [CV 4/5; 6/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600;, score=0.532 total time=   6.1s
# [CV 5/5; 6/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600
# [CV 5/5; 6/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=12, rf__n_estimators=600;, score=0.412 total time=   6.7s
# [CV 1/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100
# [CV 1/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100;, score=0.393 total time=   0.2s
# [CV 2/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100
# [CV 2/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100;, score=0.415 total time=   0.4s
# [CV 3/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100
# [CV 3/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100;, score=0.383 total time=   0.3s
# [CV 4/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100
# [CV 4/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100;, score=0.422 total time=   0.3s
# [CV 5/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100
# [CV 5/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=4, rf__n_estimators=100;, score=0.415 total time=   0.3s
# [CV 1/5; 8/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600
# [CV 1/5; 8/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600;, score=0.390 total time=   3.7s
# [CV 2/5; 8/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600
# [CV 2/5; 8/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600;, score=0.410 total time=   3.7s
# [CV 3/5; 8/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600
# [CV 3/5; 8/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600;, score=0.350 total time=   3.6s
# [CV 4/5; 8/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600
# [CV 4/5; 8/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600;, score=0.427 total time=   4.1s
# [CV 5/5; 8/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600
# [CV 5/5; 8/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=18, rf__n_estimators=600;, score=0.400 total time=   3.7s
# [CV 1/5; 9/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200
# [CV 1/5; 9/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200;, score=0.372 total time=   5.2s
# [CV 2/5; 9/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200
# [CV 2/5; 9/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200;, score=0.370 total time=   4.1s
# [CV 3/5; 9/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200
# [CV 3/5; 9/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200;, score=0.345 total time=   4.6s
# [CV 4/5; 9/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200
# [CV 4/5; 9/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200;, score=0.323 total time=   4.7s
# [CV 5/5; 9/10] START pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200
# [CV 5/5; 9/10] END pca__n_components=5, rf__criterion=entropy, rf__max_depth=4, rf__n_estimators=1200;, score=0.328 total time=   4.5s
# [CV 1/5; 10/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000
# [CV 1/5; 10/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000;, score=0.388 total time=   6.2s
# [CV 2/5; 10/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000
# [CV 2/5; 10/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000;, score=0.405 total time=   5.3s
# [CV 3/5; 10/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000
# [CV 3/5; 10/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000;, score=0.338 total time=   4.9s
# [CV 4/5; 10/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000
# [CV 4/5; 10/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000;, score=0.435 total time=   5.1s
# [CV 5/5; 10/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000
# [CV 5/5; 10/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=16, rf__n_estimators=1000;, score=0.405 total time=   5.0s
#
# Accuracy: 0.46049999999999996
#
# Best parameters(RF): {'memory': None, 'steps': [('scaling', StandardScaler()), ('pca', PCA(n_components=9)), ('rf', RandomForestClassifier(criterion='entropy', max_depth=12, n_estimators=600))], 'verbose': False, 'scaling': StandardScaler(), 'pca': PCA(n_components=9), 'rf': RandomForestClassifier(criterion='entropy', max_depth=12, n_estimators=600), 'scaling__copy': True, 'scaling__with_mean': True, 'scaling__with_std': True, 'pca__copy': True, 'pca__iterated_power': 'auto', 'pca__n_components': 9, 'pca__n_oversamples': 10, 'pca__power_iteration_normalizer': 'auto', 'pca__random_state': None, 'pca__svd_solver': 'auto', 'pca__tol': 0.0, 'pca__whiten': False, 'rf__bootstrap': True, 'rf__ccp_alpha': 0.0, 'rf__class_weight': None, 'rf__criterion': 'entropy', 'rf__max_depth': 12, 'rf__max_features': 'sqrt', 'rf__max_leaf_nodes': None, 'rf__max_samples': None, 'rf__min_impurity_decrease': 0.0, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__min_weight_fraction_leaf': 0.0, 'rf__n_estimators': 600, 'rf__n_jobs': None, 'rf__oob_score': False, 'rf__random_state': None, 'rf__verbose': 0, 'rf__warm_start': False}

# %% [markdown]
# ### 4. Bayesian Optimization with Gaussian Process
